# %% [markdown]
# <a href="https://colab.research.google.com/github/gangerz/SkillTreePython-DeepLearning/blob/main/00.%EC%B6%94%EA%B0%80%ED%95%99%EC%8A%B5/ch00_02_OpenCV%EA%B8%B0%EC%B4%88_%EB%8F%84%ED%98%95%EA%B7%B8%EB%A6%AC%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ch00.02. OpenCV기초 - 도형 그리기
#
# ---
# * 날짜:2022-06-16
# * 이름:윤예현
#
# ## 학습내용
#     - 이미지 크롭
#     - 도형 그리기
#
# ## 학습자료
# - [OpenCV 홈페이지](https://opencv.org/)
#
# - [OpenCV-pythoin Documentation](https://opencv-python.readthedocs.io/en/latest/)

# %% [markdown]
# ```
# import numpy as np
# import matplotlib.pyplot as plt
# import cv2
# from google.colab.patches import cv2_imshow
# cv2.__version__
# ```

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
from google.colab.patches import cv2_imshow
cv2.__version__
# Out:
# '4.1.2'

# %% [markdown]
# ## 이미지 준비
# ---

# %%
path = 'sea.png'
img = cv2. imread(path)
print(img.shape)
h, w, c = img.shape
print('*세로:',h)
print('*가로:',w)
print('*체널:',c)
cv2_imshow(img)
# Out:
# (382, 635, 3)
# *세로: 382
# *가로: 635
# *체널: 3
# <PIL.Image.Image image mode=RGB size=635x382 at 0x7FC38B54BA50>

# %% [markdown]
# ### **| 색깔 파라미터 설정**

# %%
B = 10 #@param{type:"slider", min:0, max:255}
G = 248 #@param{type:"slider", min:0, max:255}
R = 122 #@param{type:"slider", min:0, max:255}
shape = (100,100,3)
value = (B,G,R)
도화지 = np.full(shape, value, np.uint8)
#print(도화지)
cv2_imshow(도화지)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FC38C6555D0>

# %% [markdown]
# ## 이미지 크롭
# ---

# %% [markdown]
# ### **| 슬라이싱을 이용한 이미지 크롭**

# %%
#슬라이싱
croped = img[0:100, 0:100] # 세로를 0부터 100 픽셀만 뽑고, 가로도 0~100 픽셀만 뽑는다.
cv2_imshow(croped)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FC38C65F210>

# %% [markdown]
# #### **크롭 파라미터 설정**

# %%
X_start = 205 #@param{type:"slider", min:0, max:635, step : 1}
X_end = 497 #@param{type:"slider", min:0, max:635, step : 1}
Y_start = 51 #@param{type:"slider", min:0, max:382, step : 1}
Y_end = 278 #@param{type:"slider", min:0, max:382, step : 1}


croped = img[ Y_start:Y_end,X_start:X_end]
cv2_imshow(croped)
# Out:
# <PIL.Image.Image image mode=RGB size=292x227 at 0x7FC38B550990>

# %% [markdown]
# ## 도형 그리기
# ---

# %% [markdown]
# ### **| Line 그리기**
#
# Start와 End 점을 연결하여 직선을 그립니다.
#
# #### `cv2.line(img, start, end, color, thickness)`
# * Parameters
#   * img – 그림을 그릴 이미지 파일
#   * start – 시작 좌표(ex; (0,0))
#   * end – 종료 좌표(ex; (500. 500))
#   * color – BGR형태의 Color(ex; (255, 0, 0) -> Blue)
#   * thickness (int) – 선의 두께. pixel

# %%
cv2.line(img, (X_start, Y_start), (X_end, Y_end), value, 10)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=635x382 at 0x7FC38B5DE510>

# %% [markdown]
# ### **| 사각형 그리기**
#
# top-left corner와 bottom-right corner점을 연결하는 사각형을 그립니다.
#
# #### `cv2.rectangle(img, start, end, color, thickness)`
# * Parameters
#   * img – 그림을 그릴 이미지
#   * start – 시작 좌표(ex; (0,0))
#   * end – 종료 좌표(ex; (500. 500))
#   * color – BGR형태의 Color(ex; (255, 0, 0) -> Blue)
#   * thickness (int) – 선의 두께. pixel
#
# * Sample Code
# ```
# img = cv2.rectangle(img, (384, 0), (510, 128), (0,255,0), 3)
# ```

# %%
cv2.rectangle(img, (X_start, Y_start), (X_end, Y_end), value,20)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=635x382 at 0x7FC38B5BDAD0>

# %% [markdown]
# ### **| 원 그리기**
#
# top-left corner와 bottom-right corner점을 연결하는 사각형을 그립니다.
#
# #### `cv2.rectangle(img, start, end, color, thickness)`
# * Parameters
#   * img – 그림을 그릴 이미지
#   * center – 원의 중심 좌표(x, y)
#   * radian – 반지름
#   * color – BGR형태의 Color
#   * thickness – 선의 두께, -1 이면 원 안쪽을 채움
#
# * Sample Code
# ```
# img = cv2.circle(img, (447,63), 63, (0,0,255), -1)
# ```

# %%
img = cv2.circle(img, (X_start,Y_start), 50, value, 5)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=635x382 at 0x7FC38B4F5F10>

# %% [markdown]
# ### **| 텍스트 추가**
#
# #### `cv2.putText(img, text, org, font, fontSacle, color, thickness)`
# * Parameters
#  * img – image
#  * text – 표시할 문자열
#  * org – 문자열이 표시될 위치. 문자열의 bottom-left corner점
#  * font – font type. CV2.FONT_XXX
#  * fontSacle – Font Size
#  * color – fond color
#  * thickness - 선의 두께
#
# * Sample Code
# ```
# cv2.putText(img, 'OpenCV', (10,500), cv2.FONT_HERSHEY_SIMPLEX, 4, (255,255,255), 2)
# ```

# %%
cv2.putText(img,'Hello~~', (X_start, Y_start), cv2.FONT_ITALIC,2,value,2)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=635x382 at 0x7FC38B5DE350>

# %% [markdown]
# ## 예제
# ---
#
# * 흰도화지에 그림을 그려보자

# %%
shape = (100, 100, 3)
value = (255, 255, 255)
흰도화지 = np.full(shape, value, np.uint8)
plt.imshow(흰도화지)
#cv2.line(흰도화지, (0,0), (100,100), (0,255,0),5)
#plt.imshow(흰도화지)

# %% [markdown]
# #### **예제 01**
#
# OpenCV를 이용해 이미지에 아래와 같이 도형을 그려보세요
#
# ![](https://github.com/yebiny/SkillTreePython-DeepLearning/blob/main/imgs/cv2_1.png?raw=true)

# %%
흰도화지 = cv2.rectangle(흰도화지, (10, 50), (20, 60), (255,0,0),2)
흰도화지 = cv2.line(흰도화지, (30, 50), (40, 60), (255,0,0),2)
흰도화지 = cv2.circle(흰도화지, (55,55), 5, (255,0,0),2)
흰도화지 = cv2.putText(흰도화지,'Hello', (65, 60), cv2.FONT_ITALIC,0.3,(255,0,0),1)
plt.imshow(흰도화지)

# %% [markdown]
# #### **예제 02**
#
# OpenCV를 이용해 이미지에 아래와 같이 도형을 그려보세요
#
#
# ![](https://github.com/yebiny/SkillTreePython-DeepLearning/blob/main/imgs/cv2_2.png?raw=true)

# %%
흰도화지 = cv2.rectangle(흰도화지, (0, 0), (20, 20), (255,0,0),2)
흰도화지 = cv2.rectangle(흰도화지, (20, 20), (40, 40), (255,0,0),2)
흰도화지 = cv2.rectangle(흰도화지, (40, 40), (60, 60), (255,0,0),2)
흰도화지 = cv2.rectangle(흰도화지, (60, 60), (80, 80), (255,0,0),2)
흰도화지 = cv2.rectangle(흰도화지, (80, 80), (100,100), (255,0,0),2)

흰도화지 = cv2.circle(흰도화지, (20,80), 20, (255,0,0),-1)
흰도화지 = cv2.circle(흰도화지, (80,20), 20, (255,0,0),-1)
흰도화지 = cv2.circle(흰도화지, (20,80), 5, (0,0,0),-1)
흰도화지 = cv2.circle(흰도화지, (80,20), 5, (0,0,0),-1)
흰도화지 = cv2.circle(흰도화지, (20,80), 15, (0,0,0),5)
흰도화지 = cv2.circle(흰도화지, (80,20), 15, (0,0,0),5)

cv2.line(흰도화지, (60,20), (100,20), (0,0,0),5)

plt.imshow(흰도화지)
